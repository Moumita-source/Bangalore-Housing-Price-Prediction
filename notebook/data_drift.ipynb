# %%
import pandas as pd

# %%
from evidently.report import Report 
from evidently.metrics import DataDriftPreset, TargetDriftPreset
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from evidently.report import Report
#       2 from evidently.metrics import DataDriftPreset, TargetDriftPreset
#
# File c:\Users\DELL\.conda\envs\housing\lib\site-packages\evidently\report\__init__.py:1
# ----> 1 from .report import Report
#
# File c:\Users\DELL\.conda\envs\housing\lib\site-packages\evidently\report\report.py:12
#       9 import pandas as pd
#      11 from evidently import ColumnMapping
# ---> 12 from evidently.base_metric import InputData
#      13 from evidently.base_metric import Metric
#      14 from evidently.metric_preset.metric_preset import MetricPreset
#
# File c:\Users\DELL\.conda\envs\housing\lib\site-packages\evidently\base_metric.py:22
#      19 from pydantic import BaseConfig
#      20 from pydantic import BaseModel
# ...
