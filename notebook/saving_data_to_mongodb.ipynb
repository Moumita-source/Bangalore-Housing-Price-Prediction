# %%
import pandas as pd

# %%
import pymongo

# %%
df = pd.read_csv('Bengaluru_House_Data.csv')

# %%
## dataframe should be converted to dict before we push it to mongodb
data = df.to_dict(orient = 'records')

# %%
data
# Out:
# [{'area_type': 'Super built-up  Area',
#   'availability': '19-Dec',
#   'location': 'Electronic City Phase II',
#   'size': '2 BHK',
#   'society': 'Coomee ',
#   'total_sqft': '1056',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 39.07},
#  {'area_type': 'Plot  Area',
#   'availability': 'Ready To Move',
#   'location': 'Chikka Tirupathi',
#   'size': '4 Bedroom',
#   'society': 'Theanmp',
#   'total_sqft': '2600',
#   'bath': 5.0,
#   'balcony': 3.0,
#   'price': 120.0},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Uttarahalli',
#   'size': '3 BHK',
#   'society': nan,
#   'total_sqft': '1440',
#   'bath': 2.0,
#   'balcony': 3.0,
#   'price': 62.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Lingadheeranahalli',
#   'size': '3 BHK',
#   'society': 'Soiewre',
#   'total_sqft': '1521',
#   'bath': 3.0,
#   'balcony': 1.0,
#   'price': 95.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Kothanur',
#   'size': '2 BHK',
#   'society': nan,
#   'total_sqft': '1200',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 51.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Whitefield',
#   'size': '2 BHK',
#   'society': 'DuenaTa',
#   'total_sqft': '1170',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 38.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': '18-May',
#   'location': 'Old Airport Road',
#   'size': '4 BHK',
#   'society': 'Jaades ',
#   'total_sqft': '2732',
#   'bath': 4.0,
#   'balcony': nan,
#   'price': 204.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Rajaji Nagar',
#   'size': '4 BHK',
#   'society': 'Brway G',
#   'total_sqft': '3300',
#   'bath': 4.0,
#   'balcony': nan,
#   'price': 600.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Marathahalli',
#   'size': '3 BHK',
#   'society': nan,
#   'total_sqft': '1310',
#   'bath': 3.0,
#   'balcony': 1.0,
#   'price': 63.25},
#  {'area_type': 'Plot  Area',
#   'availability': 'Ready To Move',
#   'location': 'Gandhi Bazar',
#   'size': '6 Bedroom',
#   'society': nan,
#   'total_sqft': '1020',
#   'bath': 6.0,
#   'balcony': nan,
#   'price': 370.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': '18-Feb',
#   'location': 'Whitefield',
#   'size': '3 BHK',
#   'society': nan,
#   'total_sqft': '1800',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 70.0},
#  {'area_type': 'Plot  Area',
#   'availability': 'Ready To Move',
#   'location': 'Whitefield',
#   'size': '4 Bedroom',
#   'society': 'Prrry M',
#   'total_sqft': '2785',
#   'bath': 5.0,
#   'balcony': 3.0,
#   'price': 295.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': '7th Phase JP Nagar',
#   'size': '2 BHK',
#   'society': 'Shncyes',
#   'total_sqft': '1000',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 38.0},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Gottigere',
#   'size': '2 BHK',
#   'society': nan,
#   'total_sqft': '1100',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 40.0},
#  {'area_type': 'Plot  Area',
#   'availability': 'Ready To Move',
#   'location': 'Sarjapur',
#   'size': '3 Bedroom',
#   'society': 'Skityer',
#   'total_sqft': '2250',
#   'bath': 3.0,
#   'balcony': 2.0,
#   'price': 148.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Mysore Road',
#   'size': '2 BHK',
#   'society': 'PrntaEn',
#   'total_sqft': '1175',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 73.5},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Bisuvanahalli',
#   'size': '3 BHK',
#   'society': 'Prityel',
#   'total_sqft': '1180',
#   'bath': 3.0,
#   'balcony': 2.0,
#   'price': 48.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Raja Rajeshwari Nagar',
#   'size': '3 BHK',
#   'society': 'GrrvaGr',
#   'total_sqft': '1540',
#   'bath': 3.0,
#   'balcony': 3.0,
#   'price': 60.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Ramakrishnappa Layout',
#   'size': '3 BHK',
#   'society': 'PeBayle',
#   'total_sqft': '2770',
#   'bath': 4.0,
#   'balcony': 2.0,
#   'price': 290.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Manayata Tech Park',
#   'size': '2 BHK',
#   'society': nan,
#   'total_sqft': '1100',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 48.0},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Kengeri',
#   'size': '1 BHK',
#   'society': nan,
#   'total_sqft': '600',
#   'bath': 1.0,
#   'balcony': 1.0,
#   'price': 15.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': '19-Dec',
#   'location': 'Binny Pete',
#   'size': '3 BHK',
#   'society': 'She 2rk',
#   'total_sqft': '1755',
#   'bath': 3.0,
#   'balcony': 1.0,
#   'price': 122.0},
#  {'area_type': 'Plot  Area',
#   'availability': 'Ready To Move',
#   'location': 'Thanisandra',
#   'size': '4 Bedroom',
#   'society': 'Soitya ',
#   'total_sqft': '2800',
#   'bath': 5.0,
#   'balcony': 2.0,
#   'price': 380.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Bellandur',
#   'size': '3 BHK',
#   'society': nan,
#   'total_sqft': '1767',
#   'bath': 3.0,
#   'balcony': 1.0,
#   'price': 103.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': '18-Nov',
#   'location': ' Thanisandra',
#   'size': '1 RK',
#   'society': 'Bhe 2ko',
#   'total_sqft': '510',
#   'bath': 1.0,
#   'balcony': 0.0,
#   'price': 25.25},
#  {'area_type': 'Super built-up  Area',
#   'availability': '18-May',
#   'location': 'Mangammanapalya',
#   'size': '3 BHK',
#   'society': nan,
#   'total_sqft': '1250',
#   'bath': 3.0,
#   'balcony': 2.0,
#   'price': 56.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Electronic City',
#   'size': '2 BHK',
#   'society': 'Itelaa ',
#   'total_sqft': '660',
#   'bath': 1.0,
#   'balcony': 1.0,
#   'price': 23.1},
#  {'area_type': 'Built-up  Area',
#   'availability': '20-Dec',
#   'location': 'Whitefield',
#   'size': '3 BHK',
#   'society': nan,
#   'total_sqft': '1610',
#   'bath': 3.0,
#   'balcony': 2.0,
#   'price': 81.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': '17-Oct',
#   'location': 'Ramagondanahalli',
#   'size': '2 BHK',
#   'society': 'ViistLa',
#   'total_sqft': '1151',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 48.77},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Electronic City',
#   'size': '3 BHK',
#   'society': 'KBityo ',
#   'total_sqft': '1025',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 47.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': '19-Dec',
#   'location': 'Yelahanka',
#   'size': '4 BHK',
#   'society': 'LedorSa',
#   'total_sqft': '2100 - 2850',
#   'bath': 4.0,
#   'balcony': 0.0,
#   'price': 186.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Bisuvanahalli',
#   'size': '3 BHK',
#   'society': 'Prityel',
#   'total_sqft': '1075',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 35.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Hebbal',
#   'size': '3 BHK',
#   'society': 'Mahosya',
#   'total_sqft': '1760',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 123.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Raja Rajeshwari Nagar',
#   'size': '3 BHK',
#   'society': 'GrrvaGr',
#   'total_sqft': '1693',
#   'bath': 3.0,
#   'balcony': 3.0,
#   'price': 57.39},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Kasturi Nagar',
#   'size': '3 BHK',
#   'society': 'Kantsce',
#   'total_sqft': '1925',
#   'bath': 3.0,
#   'balcony': nan,
#   'price': 125.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': '21-Dec',
#   'location': 'Kanakpura Road',
#   'size': '2 BHK',
#   'society': 'PrarePa',
#   'total_sqft': '700',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 36.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Electronics City Phase 1',
#   'size': '2 BHK',
#   'society': nan,
#   'total_sqft': '1070',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 45.5},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Kundalahalli',
#   'size': '3 BHK',
#   'society': 'Dieldli',
#   'total_sqft': '1724',
#   'bath': 3.0,
#   'balcony': 2.0,
#   'price': 125.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Chikkalasandra',
#   'size': '3 BHK',
#   'society': nan,
#   'total_sqft': '1290',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 56.12},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Uttarahalli',
#   'size': '2 BHK',
#   'society': nan,
#   'total_sqft': '1143',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 45.0},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Murugeshpalya',
#   'size': '2 BHK',
#   'society': 'Gentson',
#   'total_sqft': '1296',
#   'bath': 2.0,
#   'balcony': nan,
#   'price': 81.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': '19-Dec',
#   'location': 'Sarjapur  Road',
#   'size': '3 BHK',
#   'society': 'Soini T',
#   'total_sqft': '1254',
#   'bath': 3.0,
#   'balcony': 2.0,
#   'price': 38.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Ganga Nagar',
#   'size': '1 BHK',
#   'society': 'Ceove G',
#   'total_sqft': '600',
#   'bath': 1.0,
#   'balcony': 0.0,
#   'price': 38.0},
#  {'area_type': 'Plot  Area',
#   'availability': 'Ready To Move',
#   'location': 'Yelahanka',
#   'size': '1 Bedroom',
#   'society': nan,
#   'total_sqft': '660',
#   'bath': 1.0,
#   'balcony': 0.0,
#   'price': 48.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': '19-Sep',
#   'location': 'Kanakpura Road',
#   'size': '2 BHK',
#   'society': 'Soazak ',
#   'total_sqft': '1330.74',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 91.79},
#  {'area_type': 'Plot  Area',
#   'availability': 'Ready To Move',
#   'location': 'HSR Layout',
#   'size': '8 Bedroom',
#   'society': nan,
#   'total_sqft': '600',
#   'bath': 9.0,
#   'balcony': nan,
#   'price': 200.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Doddathoguru',
#   'size': '2 BHK',
#   'society': 'LancyRe',
#   'total_sqft': '970',
#   'bath': 2.0,
#   'balcony': 0.0,
#   'price': 33.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': '20-Sep',
#   'location': 'Whitefield',
#   'size': '2 BHK',
#   'society': 'Goted U',
#   'total_sqft': '1459',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 94.82},
#  {'area_type': 'Plot  Area',
#   'availability': 'Ready To Move',
#   'location': 'KR Puram',
#   'size': '2 Bedroom',
#   'society': nan,
#   'total_sqft': '800',
#   'bath': 1.0,
#   'balcony': 1.0,
#   'price': 130.0},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Himagiri Meadows',
#   'size': '2 BHK',
#   'society': nan,
#   'total_sqft': '869',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 36.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Adarsh Nagar',
#   'size': '2 BHK',
#   'society': 'Bhncyis',
#   'total_sqft': '1270',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 50.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': '18-Mar',
#   'location': 'Bhoganhalli',
#   'size': '3 BHK',
#   'society': 'Rosha I',
#   'total_sqft': '1670',
#   'bath': 3.0,
#   'balcony': 1.0,
#   'price': 99.0},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Whitefield',
#   'size': '3 BHK',
#   'society': 'Suent V',
#   'total_sqft': '2010',
#   'bath': 3.0,
#   'balcony': 2.0,
#   'price': 91.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Lakshminarayana Pura',
#   'size': '2 BHK',
#   'society': 'RothaVa',
#   'total_sqft': '1185',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 75.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Yelahanka',
#   'size': '3 BHK',
#   'society': 'NCowsar',
#   'total_sqft': '1600',
#   'bath': 2.0,
#   'balcony': 3.0,
#   'price': 75.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Begur Road',
#   'size': '2 BHK',
#   'society': 'Dhalsh ',
#   'total_sqft': '1200',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 44.0},
#  {'area_type': 'Built-up  Area',
#   'availability': '20-Feb',
#   'location': 'Devanahalli',
#   'size': '4 Bedroom',
#   'society': 'BrereAt',
#   'total_sqft': '3010 - 3410',
#   'bath': nan,
#   'balcony': nan,
#   'price': 192.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Ramakrishnappa Layout',
#   'size': '2 BHK',
#   'society': 'PeBayle',
#   'total_sqft': '1500',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 185.0},
#  {'area_type': 'Plot  Area',
#   'availability': 'Ready To Move',
#   'location': 'Murugeshpalya',
#   'size': '6 Bedroom',
#   'society': nan,
#   'total_sqft': '1407',
#   'bath': 4.0,
#   'balcony': 1.0,
#   'price': 150.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Govindaraja Nagar Ward',
#   'size': '2 BHK',
#   'society': nan,
#   'total_sqft': '840',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 45.0},
#  {'area_type': 'Plot  Area',
#   'availability': 'Ready To Move',
#   'location': 'Tharabanahalli',
#   'size': '3 Bedroom',
#   'society': nan,
#   'total_sqft': '4395',
#   'bath': 3.0,
#   'balcony': 2.0,
#   'price': 240.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Ganga Nagar',
#   'size': '2 BHK',
#   'society': 'Laavevi',
#   'total_sqft': '845',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 55.0},
#  {'area_type': 'Plot  Area',
#   'availability': 'Ready To Move',
#   'location': 'Whitefield',
#   'size': '4 Bedroom',
#   'society': 'Chranya',
#   'total_sqft': '5700',
#   'bath': 5.0,
#   'balcony': 3.0,
#   'price': 650.0},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Varthur',
#   'size': '2 BHK',
#   'society': 'HioraTr',
#   'total_sqft': '1160',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 44.0},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Bommanahalli',
#   'size': '8 Bedroom',
#   'society': nan,
#   'total_sqft': '3000',
#   'bath': 8.0,
#   'balcony': 0.0,
#   'price': 140.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Doddathoguru',
#   'size': '2 BHK',
#   'society': nan,
#   'total_sqft': '1100',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 62.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': '18-Apr',
#   'location': 'Gunjur',
#   'size': '2 BHK',
#   'society': 'BMineis',
#   'total_sqft': '1140',
#   'bath': 2.0,
#   'balcony': 3.0,
#   'price': 43.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Marathahalli',
#   'size': '2 BHK',
#   'society': nan,
#   'total_sqft': '1220',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 57.0},
#  {'area_type': 'Plot  Area',
#   'availability': 'Ready To Move',
#   'location': 'Devarachikkanahalli',
#   'size': '8 Bedroom',
#   'society': nan,
#   'total_sqft': '1350',
#   'bath': 7.0,
#   'balcony': 0.0,
#   'price': 85.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Kanakpura Road',
#   'size': '2 BHK',
#   'society': nan,
#   'total_sqft': '1005',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 36.68},
#  {'area_type': 'Plot  Area',
#   'availability': 'Ready To Move',
#   'location': 'Double Road',
#   'size': '3 Bedroom',
#   'society': nan,
#   'total_sqft': '500',
#   'bath': 3.0,
#   'balcony': 2.0,
#   'price': 100.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': '20-Aug',
#   'location': 'Begur Road',
#   'size': '2 BHK',
#   'society': 'Pruthg ',
#   'total_sqft': '1358',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 80.58},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Hegde Nagar',
#   'size': '3 BHK',
#   'society': 'Sonosty',
#   'total_sqft': '1569',
#   'bath': 3.0,
#   'balcony': 1.0,
#   'price': 101.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': '18-Apr',
#   'location': 'Haralur Road',
#   'size': '2 BHK',
#   'society': 'SNnia E',
#   'total_sqft': '1240',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 70.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Hennur Road',
#   'size': '3 BHK',
#   'society': 'Anavi B',
#   'total_sqft': '2089',
#   'bath': 3.0,
#   'balcony': 2.0,
#   'price': 140.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Kothannur',
#   'size': '2 BHK',
#   'society': nan,
#   'total_sqft': '1206',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 48.23},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Kalena Agrahara',
#   'size': '2 BHK',
#   'society': nan,
#   'total_sqft': '1150',
#   'bath': 2.0,
#   'balcony': 3.0,
#   'price': 40.0},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Cholanayakanahalli',
#   'size': '3 BHK',
#   'society': 'Viony H',
#   'total_sqft': '2511',
#   'bath': 3.0,
#   'balcony': 3.0,
#   'price': 205.0},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Kaval Byrasandra',
#   'size': '2 BHK',
#   'society': nan,
#   'total_sqft': '460',
#   'bath': 1.0,
#   'balcony': 0.0,
#   'price': 22.0},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'ISRO Layout',
#   'size': '6 Bedroom',
#   'society': nan,
#   'total_sqft': '4400',
#   'bath': 6.0,
#   'balcony': 3.0,
#   'price': 250.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Kodanda Reddy Layout',
#   'size': '3 BHK',
#   'society': 'AdentEl',
#   'total_sqft': '1660',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 105.0},
#  {'area_type': 'Built-up  Area',
#   'availability': '18-Oct',
#   'location': 'Hennur Road',
#   'size': '4 Bedroom',
#   'society': 'Gollela',
#   'total_sqft': '2957 - 3450',
#   'bath': nan,
#   'balcony': nan,
#   'price': 224.5},
#  {'area_type': 'Super built-up  Area',
#   'availability': '19-Mar',
#   'location': 'Yelahanka',
#   'size': '2 BHK',
#   'society': 'Niareum',
#   'total_sqft': '1326',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 78.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Garudachar Palya',
#   'size': '3 BHK',
#   'society': nan,
#   'total_sqft': '1325',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 60.8},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'EPIP Zone',
#   'size': '3 BHK',
#   'society': 'SJlynro',
#   'total_sqft': '1499',
#   'bath': 5.0,
#   'balcony': 2.0,
#   'price': 102.0},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Hegde Nagar',
#   'size': '6 Bedroom',
#   'society': nan,
#   'total_sqft': '3000',
#   'bath': 7.0,
#   'balcony': 2.0,
#   'price': 210.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Kanakpura Road',
#   'size': '3 BHK',
#   'society': nan,
#   'total_sqft': '1665',
#   'bath': 3.0,
#   'balcony': 2.0,
#   'price': 88.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': '17-Sep',
#   'location': 'Dasanapura',
#   'size': '2 BHK',
#   'society': 'Tavenew',
#   'total_sqft': '708',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 37.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Kasavanhalli',
#   'size': '2 BHK',
#   'society': 'Srire S',
#   'total_sqft': '1060',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 58.06},
#  {'area_type': 'Plot  Area',
#   'availability': 'Ready To Move',
#   'location': 'Rajaji Nagar',
#   'size': '6 Bedroom',
#   'society': nan,
#   'total_sqft': '710',
#   'bath': 6.0,
#   'balcony': 3.0,
#   'price': 160.0},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Sanjay nagar',
#   'size': '2 BHK',
#   'society': 'Saenti ',
#   'total_sqft': '1000',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 70.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': '18-Dec',
#   'location': 'Electronic City',
#   'size': '2 BHK',
#   'society': nan,
#   'total_sqft': '1000',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 28.88},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': ' Mysore Highway',
#   'size': '3 BHK',
#   'society': nan,
#   'total_sqft': '1450',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 70.0},
#  {'area_type': 'Plot  Area',
#   'availability': 'Ready To Move',
#   'location': 'ISRO Layout',
#   'size': '4 Bedroom',
#   'society': nan,
#   'total_sqft': '1200',
#   'bath': 4.0,
#   'balcony': 2.0,
#   'price': 155.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': '17-Aug',
#   'location': 'Thanisandra',
#   'size': '2 BHK',
#   'society': 'Bhmesy ',
#   'total_sqft': '1296',
#   'bath': 2.0,
#   'balcony': 3.0,
#   'price': 80.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Domlur',
#   'size': '3 BHK',
#   'society': nan,
#   'total_sqft': '1540',
#   'bath': 3.0,
#   'balcony': 2.0,
#   'price': 90.0},
#  {'area_type': 'Plot  Area',
#   'availability': 'Ready To Move',
#   'location': 'Kengeri',
#   'size': '4 Bedroom',
#   'society': 'Goardth',
#   'total_sqft': '2894',
#   'bath': 4.0,
#   'balcony': 1.0,
#   'price': 245.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Sarjapura - Attibele Road',
#   'size': '3 BHK',
#   'society': nan,
#   'total_sqft': '1330',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 48.0},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Devasthanagalu',
#   'size': '2 BHK',
#   'society': nan,
#   'total_sqft': '1200',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 65.0},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'T Dasarahalli',
#   'size': '3 Bedroom',
#   'society': nan,
#   'total_sqft': '1200',
#   'bath': 3.0,
#   'balcony': 1.0,
#   'price': 90.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Yeshwanthpur',
#   'size': '3 BHK',
#   'society': 'IBityin',
#   'total_sqft': '2502',
#   'bath': 3.0,
#   'balcony': 3.0,
#   'price': 138.0},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Chandapura',
#   'size': '2 BHK',
#   'society': 'KHityry',
#   'total_sqft': '650',
#   'bath': 1.0,
#   'balcony': 1.0,
#   'price': 17.0},
#  {'area_type': 'Plot  Area',
#   'availability': 'Ready To Move',
#   'location': 'Kothanur',
#   'size': '3 Bedroom',
#   'society': 'BDensar',
#   'total_sqft': '2400',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 150.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Green View Layout',
#   'size': '2 BHK',
#   'society': 'Makeser',
#   'total_sqft': '1007',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 43.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Shantiniketan Layout',
#   'size': '2 BHK',
#   'society': 'Maest N',
#   'total_sqft': '1200',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 50.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Peenya',
#   'size': '2 BHK',
#   'society': nan,
#   'total_sqft': '966',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 49.9},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Nagarbhavi',
#   'size': '3 BHK',
#   'society': nan,
#   'total_sqft': '1630',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 98.0},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Rajaji Nagar',
#   'size': '3 BHK',
#   'society': 'Brway G',
#   'total_sqft': '1640',
#   'bath': 3.0,
#   'balcony': 2.0,
#   'price': 229.0},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Jalahalli West',
#   'size': '2 BHK',
#   'society': nan,
#   'total_sqft': '782',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 55.68},
#  {'area_type': 'Super built-up  Area',
#   'availability': '19-Apr',
#   'location': 'Devanahalli',
#   'size': '2 BHK',
#   'society': 'Oznuean',
#   'total_sqft': '1260',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 66.78},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Lakshmiamma Garden',
#   'size': '3 BHK',
#   'society': nan,
#   'total_sqft': '1800',
#   'bath': 3.0,
#   'balcony': 3.0,
#   'price': 120.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Byatarayanapura',
#   'size': '3 BHK',
#   'society': 'Reeroce',
#   'total_sqft': '1413',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 75.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Whitefield',
#   'size': '2 BHK',
#   'society': 'Sonviik',
#   'total_sqft': '1116',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 51.91},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Electronic City',
#   'size': '3 BHK',
#   'society': 'DSgmax ',
#   'total_sqft': '1530',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 45.9},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Ramamurthy Nagar',
#   'size': '4 Bedroom',
#   'society': nan,
#   'total_sqft': '3700',
#   'bath': 4.0,
#   'balcony': 1.0,
#   'price': 225.0},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Sarjapur  Road',
#   'size': '3 Bedroom',
#   'society': 'Cetattu',
#   'total_sqft': '2497',
#   'bath': 3.0,
#   'balcony': 2.0,
#   'price': 140.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Kengeri',
#   'size': '3 BHK',
#   'society': 'Vaens G',
#   'total_sqft': '1540',
#   'bath': 2.0,
#   'balcony': 3.0,
#   'price': 64.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': '18-Dec',
#   'location': 'Thanisandra',
#   'size': '3 BHK',
#   'society': nan,
#   'total_sqft': '1436',
#   'bath': 3.0,
#   'balcony': 1.0,
#   'price': 74.75},
#  {'area_type': 'Super built-up  Area',
#   'availability': '18-Jun',
#   'location': 'Malleshwaram',
#   'size': '2 BHK',
#   'society': nan,
#   'total_sqft': '1100',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 75.0},
#  {'area_type': 'Plot  Area',
#   'availability': 'Ready To Move',
#   'location': 'Hennur Road',
#   'size': '2 Bedroom',
#   'society': nan,
#   'total_sqft': '276',
#   'bath': 3.0,
#   'balcony': 3.0,
#   'price': 23.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Thanisandra',
#   'size': '3 BHK',
#   'society': 'Moity S',
#   'total_sqft': '1427',
#   'bath': 3.0,
#   'balcony': 2.0,
#   'price': 120.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Akshaya Nagar',
#   'size': '3 BHK',
#   'society': 'HiahsLa',
#   'total_sqft': '2061',
#   'bath': 3.0,
#   'balcony': 1.0,
#   'price': 200.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': '18-Mar',
#   'location': 'Hebbal',
#   'size': '4 BHK',
#   'society': 'SNontle',
#   'total_sqft': '3067 - 8156',
#   'bath': 4.0,
#   'balcony': 0.0,
#   'price': 477.0},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Shampura',
#   'size': '4 BHK',
#   'society': nan,
#   'total_sqft': '2650',
#   'bath': 4.0,
#   'balcony': 2.0,
#   'price': 150.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': '22-Dec',
#   'location': 'Devanahalli',
#   'size': '3 BHK',
#   'society': 'Sabixtt',
#   'total_sqft': '1282',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 68.52},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Kadugodi',
#   'size': '2 BHK',
#   'society': nan,
#   'total_sqft': '1050',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 34.0},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'LB Shastri Nagar',
#   'size': '3 BHK',
#   'society': 'Sragei ',
#   'total_sqft': '1600',
#   'bath': 3.0,
#   'balcony': 2.0,
#   'price': 65.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': '22-Jan',
#   'location': 'Vajarahalli',
#   'size': '2 BHK',
#   'society': nan,
#   'total_sqft': '945',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 54.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Hormavu',
#   'size': '2 BHK',
#   'society': 'SyidaCr',
#   'total_sqft': '1500',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 78.0},
#  {'area_type': 'Plot  Area',
#   'availability': 'Ready To Move',
#   'location': 'Vishwapriya Layout',
#   'size': '7 Bedroom',
#   'society': nan,
#   'total_sqft': '950',
#   'bath': 7.0,
#   'balcony': 0.0,
#   'price': 115.0},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Peenya',
#   'size': '3 BHK',
#   'society': 'Jahts H',
#   'total_sqft': '1870',
#   'bath': 3.0,
#   'balcony': 3.0,
#   'price': 110.0},
#  {'area_type': 'Plot  Area',
#   'availability': 'Ready To Move',
#   'location': 'Sarjapur',
#   'size': '3 Bedroom',
#   'society': 'Inensba',
#   'total_sqft': '1600',
#   'bath': 3.0,
#   'balcony': 1.0,
#   'price': 75.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Electronic City',
#   'size': '2 BHK',
#   'society': 'Itelaa ',
#   'total_sqft': '880',
#   'bath': 1.0,
#   'balcony': 1.0,
#   'price': 16.5},
#  {'area_type': 'Plot  Area',
#   'availability': 'Ready To Move',
#   'location': 'Ramaswamy Palya - Kammanahalli Main Road',
#   'size': '4 Bedroom',
#   'society': nan,
#   'total_sqft': '1200',
#   'bath': 4.0,
#   'balcony': 0.0,
#   'price': 210.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Kudlu Gate',
#   'size': '3 BHK',
#   'society': 'Srier P',
#   'total_sqft': '1535',
#   'bath': 3.0,
#   'balcony': 2.0,
#   'price': 83.0},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Kanakpura Road',
#   'size': '2 BHK',
#   'society': 'Wiowsri',
#   'total_sqft': '950',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 57.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': '18-Aug',
#   'location': 'Devanahalli',
#   'size': '2 BHK',
#   'society': 'Derdsig',
#   'total_sqft': '1360',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 65.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': '19-Mar',
#   'location': '8th Phase JP Nagar',
#   'size': '2 BHK',
#   'society': 'Vaarech',
#   'total_sqft': '1042 - 1105',
#   'bath': 2.0,
#   'balcony': 0.0,
#   'price': 54.005},
#  {'area_type': 'Super built-up  Area',
#   'availability': '18-May',
#   'location': 'Bommasandra Industrial Area',
#   'size': '3 BHK',
#   'society': nan,
#   'total_sqft': '1280',
#   'bath': 3.0,
#   'balcony': 1.0,
#   'price': 50.4},
#  {'area_type': 'Super built-up  Area',
#   'availability': '19-Jan',
#   'location': 'Chandra Layout',
#   'size': '3 BHK',
#   'society': 'TiaksAa',
#   'total_sqft': '1260',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 85.05},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Hennur Road',
#   'size': '8 Bedroom',
#   'society': nan,
#   'total_sqft': '5000',
#   'bath': 8.0,
#   'balcony': nan,
#   'price': 250.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': '19-Dec',
#   'location': 'Yelahanka',
#   'size': '5 BHK',
#   'society': 'LedorSa',
#   'total_sqft': '3050',
#   'bath': 5.0,
#   'balcony': 1.0,
#   'price': 213.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Kasavanhalli',
#   'size': '3 BHK',
#   'society': 'HMwerCo',
#   'total_sqft': '1563.05',
#   'bath': 3.0,
#   'balcony': 1.0,
#   'price': 105.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'ISRO Layout',
#   'size': '2 BHK',
#   'society': nan,
#   'total_sqft': '1000',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 60.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': '17-Jul',
#   'location': 'Anandapura',
#   'size': '2 BHK',
#   'society': 'ViensRK',
#   'total_sqft': '1167',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 43.76},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Vishveshwarya Layout',
#   'size': '7 BHK',
#   'society': nan,
#   'total_sqft': '4000',
#   'bath': 7.0,
#   'balcony': 2.0,
#   'price': 225.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Kothanur',
#   'size': '3 BHK',
#   'society': 'Somumys',
#   'total_sqft': '1828',
#   'bath': 3.0,
#   'balcony': nan,
#   'price': 110.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Kengeri Satellite Town',
#   'size': '2 BHK',
#   'society': 'HoiewLa',
#   'total_sqft': '890',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 35.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Basavanapura',
#   'size': '3 BHK',
#   'society': 'Dwity T',
#   'total_sqft': '1612',
#   'bath': 3.0,
#   'balcony': 3.0,
#   'price': 46.74},
#  {'area_type': 'Plot  Area',
#   'availability': 'Ready To Move',
#   'location': 'Dinnur',
#   'size': '6 Bedroom',
#   'society': nan,
#   'total_sqft': '1034',
#   'bath': 5.0,
#   'balcony': nan,
#   'price': 185.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': '19-Apr',
#   'location': 'Mysore Road',
#   'size': '3 BHK',
#   'society': 'Brama P',
#   'total_sqft': '1710',
#   'bath': 4.0,
#   'balcony': 2.0,
#   'price': 91.31},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Kannamangala',
#   'size': '2 BHK',
#   'society': 'VBownre',
#   'total_sqft': '957',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 58.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': '18-May',
#   'location': ' Devarachikkanahalli',
#   'size': '3 BHK',
#   'society': nan,
#   'total_sqft': '1250',
#   'bath': 2.0,
#   'balcony': 3.0,
#   'price': 44.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Sanjeevini Nagar',
#   'size': '3 BHK',
#   'society': 'Betatsi',
#   'total_sqft': '2795',
#   'bath': 4.0,
#   'balcony': nan,
#   'price': 235.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Hulimavu',
#   'size': '2 BHK',
#   'society': 'Prcan P',
#   'total_sqft': '1125',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 50.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': '18-Jul',
#   'location': 'Electronic City Phase II',
#   'size': '2 BHK',
#   'society': 'Sryalan',
#   'total_sqft': '1020',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 30.6},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Kalena Agrahara',
#   'size': '2 BHK',
#   'society': nan,
#   'total_sqft': '1200',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 50.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Thanisandra',
#   'size': '3 BHK',
#   'society': 'Soitya ',
#   'total_sqft': '1735',
#   'bath': 3.0,
#   'balcony': 3.0,
#   'price': 135.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Thanisandra',
#   'size': '3 BHK',
#   'society': 'G conTh',
#   'total_sqft': '2050',
#   'bath': 3.0,
#   'balcony': 1.0,
#   'price': 145.0},
#  {'area_type': 'Plot  Area',
#   'availability': 'Ready To Move',
#   'location': 'Mahalakshmi Layout',
#   'size': '4 Bedroom',
#   'society': nan,
#   'total_sqft': '3750',
#   'bath': 4.0,
#   'balcony': 0.0,
#   'price': 760.0},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Yarandahalli',
#   'size': '3 BHK',
#   'society': nan,
#   'total_sqft': '1350',
#   'bath': 2.0,
#   'balcony': 3.0,
#   'price': 48.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': '18-May',
#   'location': 'Hosa Road',
#   'size': '2 BHK',
#   'society': 'SStusan',
#   'total_sqft': '1063',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 32.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Keshava Nagar',
#   'size': '3 BHK',
#   'society': 'ETens G',
#   'total_sqft': '1904',
#   'bath': 3.0,
#   'balcony': 1.0,
#   'price': 150.0},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Whitefield',
#   'size': '4 Bedroom',
#   'society': nan,
#   'total_sqft': '4200',
#   'bath': 4.0,
#   'balcony': 2.0,
#   'price': 420.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'RMV Extension',
#   'size': '3 BHK',
#   'society': 'Hohnari',
#   'total_sqft': '2000',
#   'bath': 3.0,
#   'balcony': 1.0,
#   'price': 175.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': '18-Dec',
#   'location': 'Sarjapur',
#   'size': '2 BHK',
#   'society': 'Kinuerg',
#   'total_sqft': '1145 - 1340',
#   'bath': 2.0,
#   'balcony': 0.0,
#   'price': 43.49},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Tejaswini Nagar',
#   'size': '3 BHK',
#   'society': 'Naods W',
#   'total_sqft': '1425',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 75.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Electronic City',
#   'size': '3 BHK',
#   'society': 'GMown E',
#   'total_sqft': '1500',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 64.5},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Electronic City',
#   'size': '2 BHK',
#   'society': 'GMown E',
#   'total_sqft': '1060',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 60.0},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Jai Bheema Nagar',
#   'size': '3 BHK',
#   'society': 'Sancyra',
#   'total_sqft': '1470',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 70.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Kothnur Narayanapura',
#   'size': '6 BHK',
#   'society': nan,
#   'total_sqft': '1300',
#   'bath': 6.0,
#   'balcony': 0.0,
#   'price': 99.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Attibele',
#   'size': '1 BHK',
#   'society': 'Jae 1hu',
#   'total_sqft': '450',
#   'bath': 1.0,
#   'balcony': 1.0,
#   'price': 11.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': '18-Apr',
#   'location': 'Electronic City',
#   'size': '2 BHK',
#   'society': 'Prarkun',
#   'total_sqft': '1152',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 64.5},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Electronic City',
#   'size': '3 BHK',
#   'society': 'GMown E',
#   'total_sqft': '1350',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 56.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'CV Raman Nagar',
#   'size': '3 BHK',
#   'society': 'Srshq T',
#   'total_sqft': '1550',
#   'bath': 3.0,
#   'balcony': 3.0,
#   'price': 65.0},
#  {'area_type': 'Plot  Area',
#   'availability': 'Ready To Move',
#   'location': 'CHIKKATIRUPATHI',
#   'size': '3 Bedroom',
#   'society': nan,
#   'total_sqft': '1500',
#   'bath': 3.0,
#   'balcony': 2.0,
#   'price': 100.0},
#  {'area_type': 'Plot  Area',
#   'availability': 'Ready To Move',
#   'location': 'Kumaraswami Layout',
#   'size': '5 Bedroom',
#   'society': nan,
#   'total_sqft': '600',
#   'bath': 3.0,
#   'balcony': 2.0,
#   'price': 85.0},
#  {'area_type': 'Plot  Area',
#   'availability': 'Ready To Move',
#   'location': 'Nagavara',
#   'size': '1 Bedroom',
#   'society': nan,
#   'total_sqft': '400',
#   'bath': 1.0,
#   'balcony': 0.0,
#   'price': 14.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Malleshwaram',
#   'size': '1 BHK',
#   'society': 'Utntspa',
#   'total_sqft': '705',
#   'bath': 1.0,
#   'balcony': 2.0,
#   'price': 67.0},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Electronic City',
#   'size': '2 BHK',
#   'society': 'GMown E',
#   'total_sqft': '770',
#   'bath': 1.0,
#   'balcony': 1.0,
#   'price': 36.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Hulimavu',
#   'size': '2 BHK',
#   'society': 'Aniona ',
#   'total_sqft': '1242',
#   'bath': 2.0,
#   'balcony': 3.0,
#   'price': 51.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Hebbal Kempapura',
#   'size': '3 BHK',
#   'society': 'Goateds',
#   'total_sqft': '1700',
#   'bath': 3.0,
#   'balcony': 2.0,
#   'price': 155.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Thanisandra',
#   'size': '3 BHK',
#   'society': 'Soitya ',
#   'total_sqft': '2144',
#   'bath': 3.0,
#   'balcony': 2.0,
#   'price': 145.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': '21-Jun',
#   'location': 'Vijayanagar',
#   'size': '3 BHK',
#   'society': 'Saahaat',
#   'total_sqft': '1704',
#   'bath': 3.0,
#   'balcony': 2.0,
#   'price': 110.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Electronic City',
#   'size': '2 BHK',
#   'society': 'GMown E',
#   'total_sqft': '1070',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 52.0},
#  {'area_type': 'Plot  Area',
#   'availability': 'Ready To Move',
#   'location': '8th block Koramangala',
#   'size': '3 Bedroom',
#   'society': nan,
#   'total_sqft': '1846',
#   'bath': 3.0,
#   'balcony': 2.0,
#   'price': 300.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Jakkuru Layout',
#   'size': '2 BHK',
#   'society': nan,
#   'total_sqft': '1340',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 55.7},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Electronic City',
#   'size': '2 BHK',
#   'society': 'GMown E',
#   'total_sqft': '1025',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 46.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'KR Puram',
#   'size': '2 BHK',
#   'society': 'MCvarar',
#   'total_sqft': '1015 - 1540',
#   'bath': 2.0,
#   'balcony': 0.0,
#   'price': 56.8},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Marathahalli',
#   'size': '2 BHK',
#   'society': 'VRave E',
#   'total_sqft': '1200',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 52.0},
#  {'area_type': 'Built-up  Area',
#   'availability': '18-Dec',
#   'location': 'Kanakpura Road',
#   'size': '4 Bedroom',
#   'society': nan,
#   'total_sqft': '2250',
#   'bath': 4.0,
#   'balcony': 1.0,
#   'price': 110.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Pattandur Agrahara',
#   'size': '3 BHK',
#   'society': 'MaidoPl',
#   'total_sqft': '1550',
#   'bath': 2.0,
#   'balcony': 3.0,
#   'price': 80.0},
#  {'area_type': 'Plot  Area',
#   'availability': 'Ready To Move',
#   'location': 'Bellandur',
#   'size': '4 Bedroom',
#   'society': nan,
#   'total_sqft': '1200',
#   'bath': 5.0,
#   'balcony': nan,
#   'price': 325.0},
#  {'area_type': 'Plot  Area',
#   'availability': 'Ready To Move',
#   'location': 'Ejipura',
#   'size': '7 Bedroom',
#   'society': nan,
#   'total_sqft': '1800',
#   'bath': 7.0,
#   'balcony': 1.0,
#   'price': 250.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Marathahalli',
#   'size': '2 BHK',
#   'society': 'Aiitya ',
#   'total_sqft': '1200',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 60.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Yelahanka',
#   'size': '2 BHK',
#   'society': 'PuziaVe',
#   'total_sqft': '1327',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 98.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Kothanur',
#   'size': '2 BHK',
#   'society': nan,
#   'total_sqft': '1186',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 58.0},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'MS Pallya',
#   'size': '3 Bedroom',
#   'society': nan,
#   'total_sqft': '1783',
#   'bath': 3.0,
#   'balcony': 1.0,
#   'price': 115.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'HSR Layout',
#   'size': '3 BHK',
#   'society': 'NRosete',
#   'total_sqft': '1400',
#   'bath': 3.0,
#   'balcony': 2.0,
#   'price': 56.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Nagasandra',
#   'size': '2 BHK',
#   'society': nan,
#   'total_sqft': '980',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 48.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'EPIP Zone',
#   'size': '2 BHK',
#   'society': nan,
#   'total_sqft': '1285',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 82.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Langford Town',
#   'size': '3 BHK',
#   'society': nan,
#   'total_sqft': '912',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 70.0},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Whitefield',
#   'size': '2 BHK',
#   'society': 'Sancya ',
#   'total_sqft': '1225',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 47.6},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Whitefield',
#   'size': '2 BHK',
#   'society': nan,
#   'total_sqft': '1075',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 53.0},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Kadugodi',
#   'size': '3 BHK',
#   'society': 'MSingco',
#   'total_sqft': '1260',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 54.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Yelahanka',
#   'size': '3 BHK',
#   'society': 'Pyikad ',
#   'total_sqft': '1282',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 48.7},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Kogilu',
#   'size': '3 BHK',
#   'society': 'CaIRSCr',
#   'total_sqft': '1909',
#   'bath': 3.0,
#   'balcony': 2.0,
#   'price': 88.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Panathur',
#   'size': '2 BHK',
#   'society': 'Prcesvy',
#   'total_sqft': '1359',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 87.0},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Nagondanahalli',
#   'size': '2 BHK',
#   'society': nan,
#   'total_sqft': '1207',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 43.5},
#  {'area_type': 'Plot  Area',
#   'availability': 'Ready To Move',
#   'location': 'Padmanabhanagar',
#   'size': '4 Bedroom',
#   'society': nan,
#   'total_sqft': '1736',
#   'bath': 6.0,
#   'balcony': 0.0,
#   'price': 190.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': '20-May',
#   'location': '1st Block Jayanagar',
#   'size': '4 BHK',
#   'society': nan,
#   'total_sqft': '2850',
#   'bath': 4.0,
#   'balcony': 1.0,
#   'price': 428.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Kammasandra',
#   'size': '3 BHK',
#   'society': 'Emstael',
#   'total_sqft': '1595',
#   'bath': 3.0,
#   'balcony': 2.0,
#   'price': 65.0},
#  {'area_type': 'Built-up  Area',
#   'availability': '18-Jun',
#   'location': 'Off Sarjapur Road, ',
#   'size': '3 BHK',
#   'society': nan,
#   'total_sqft': '1798',
#   'bath': 3.0,
#   'balcony': 2.0,
#   'price': 89.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Electronics City Phase 1',
#   'size': '3 BHK',
#   'society': 'SNdri N',
#   'total_sqft': '1475',
#   'bath': 3.0,
#   'balcony': 2.0,
#   'price': 78.29},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Tala Cauvery Layout',
#   'size': '3 BHK',
#   'society': 'HodhiSa',
#   'total_sqft': '1580',
#   'bath': 3.0,
#   'balcony': 3.0,
#   'price': 100.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Dasarahalli',
#   'size': '2 BHK',
#   'society': 'Syonyph',
#   'total_sqft': '1295',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 65.0},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Magadi Road',
#   'size': '6 Bedroom',
#   'society': nan,
#   'total_sqft': '3600',
#   'bath': 6.0,
#   'balcony': 0.0,
#   'price': 141.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Electronic City',
#   'size': '1 BHK',
#   'society': 'Itvir M',
#   'total_sqft': '589',
#   'bath': 1.0,
#   'balcony': 1.0,
#   'price': 27.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Ngef Layout',
#   'size': '3 BHK',
#   'society': nan,
#   'total_sqft': '1415',
#   'bath': 3.0,
#   'balcony': 3.0,
#   'price': 78.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': '18-Dec',
#   'location': 'Sarjapur  Road',
#   'size': '3 BHK',
#   'society': 'Klark L',
#   'total_sqft': '1787',
#   'bath': 3.0,
#   'balcony': 2.0,
#   'price': 98.29},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
# ...
#   'location': 'Horamavu Banaswadi',
#   'size': '3 BHK',
#   'society': 'Asorai ',
#   'total_sqft': '1554',
#   'bath': 3.0,
#   'balcony': 2.0,
#   'price': 55.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': '18-Dec',
#   'location': 'Thanisandra',
#   'size': '2 BHK',
#   'society': 'Omter A',
#   'total_sqft': '1000 - 1285',
#   'bath': 2.0,
#   'balcony': 0.0,
#   'price': 43.415},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Bellandur',
#   'size': '5 BHK',
#   'society': nan,
#   'total_sqft': '4239',
#   'bath': 5.0,
#   'balcony': 2.0,
#   'price': 423.0},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Konanakunte',
#   'size': '2 Bedroom',
#   'society': nan,
#   'total_sqft': '884',
#   'bath': 1.0,
#   'balcony': 0.0,
#   'price': 58.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': '19-Mar',
#   'location': 'Hosa Road',
#   'size': '2 BHK',
#   'society': 'Skume R',
#   'total_sqft': '1045',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 98.89},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Marathahalli',
#   'size': '2 BHK',
#   'society': nan,
#   'total_sqft': '1019',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 49.86},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Ambedkar Nagar',
#   'size': '3 BHK',
#   'society': 'SoechHa',
#   'total_sqft': '1935',
#   'bath': 4.0,
#   'balcony': 2.0,
#   'price': 130.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Uttarahalli',
#   'size': '3 BHK',
#   'society': nan,
#   'total_sqft': '1135',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 39.73},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Lakshminarayana Pura',
#   'size': '3 BHK',
#   'society': 'RothaVa',
#   'total_sqft': '1680',
#   'bath': 3.0,
#   'balcony': 2.0,
#   'price': 150.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': '19-Jun',
#   'location': 'Hebbal',
#   'size': '4 BHK',
#   'society': 'Raard B',
#   'total_sqft': '2470',
#   'bath': 5.0,
#   'balcony': 2.0,
#   'price': 247.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': '1st Phase JP Nagar',
#   'size': '4 BHK',
#   'society': 'Prhtsok',
#   'total_sqft': '2825',
#   'bath': 4.0,
#   'balcony': 3.0,
#   'price': 250.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Hosakerehalli',
#   'size': '3 BHK',
#   'society': 'Taonte ',
#   'total_sqft': '2480',
#   'bath': 3.0,
#   'balcony': 1.0,
#   'price': 330.0},
#  {'area_type': 'Plot  Area',
#   'availability': 'Ready To Move',
#   'location': '5th Phase JP Nagar',
#   'size': '9 Bedroom',
#   'society': nan,
#   'total_sqft': '1260',
#   'bath': 11.0,
#   'balcony': nan,
#   'price': 290.0},
#  {'area_type': 'Plot  Area',
#   'availability': 'Ready To Move',
#   'location': 'Ramamurthy Nagar',
#   'size': '5 Bedroom',
#   'society': nan,
#   'total_sqft': '1800',
#   'bath': 4.0,
#   'balcony': 3.0,
#   'price': 187.0},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Kasavanhalli',
#   'size': '3 BHK',
#   'society': 'Ocrda M',
#   'total_sqft': '1799',
#   'bath': 3.0,
#   'balcony': 3.0,
#   'price': 90.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Whitefield',
#   'size': '4 Bedroom',
#   'society': 'PrOakSi',
#   'total_sqft': '3606 - 5091',
#   'bath': nan,
#   'balcony': nan,
#   'price': 304.0},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Attibele',
#   'size': '1 BHK',
#   'society': 'Jae 2hu',
#   'total_sqft': '400',
#   'bath': 1.0,
#   'balcony': 1.0,
#   'price': 11.0},
#  {'area_type': 'Built-up  Area',
#   'availability': '18-Mar',
#   'location': 'Kundalahalli',
#   'size': '2 BHK',
#   'society': 'Dieldli',
#   'total_sqft': '1047',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 82.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Kaverappa Layout',
#   'size': '2 BHK',
#   'society': 'Kesomrn',
#   'total_sqft': '1282',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 87.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'NGR Layout',
#   'size': '2 BHK',
#   'society': nan,
#   'total_sqft': '1020',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 45.9},
#  {'area_type': 'Plot  Area',
#   'availability': 'Ready To Move',
#   'location': 'Kammanahalli',
#   'size': '4 Bedroom',
#   'society': nan,
#   'total_sqft': '1080',
#   'bath': 3.0,
#   'balcony': 1.0,
#   'price': 155.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Whitefield',
#   'size': '2 BHK',
#   'society': 'UKe 2nz',
#   'total_sqft': '1495',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 79.5},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Kasavanhalli',
#   'size': '4 Bedroom',
#   'society': 'Vaidsi ',
#   'total_sqft': '3260',
#   'bath': 4.0,
#   'balcony': 1.0,
#   'price': 240.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': '17-Oct',
#   'location': 'Divya Unnathi Layout',
#   'size': '3 BHK',
#   'society': nan,
#   'total_sqft': '1611',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 64.44},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Koramangala',
#   'size': '4 BHK',
#   'society': 'K ncy R',
#   'total_sqft': '3500',
#   'bath': 5.0,
#   'balcony': 2.0,
#   'price': 425.0},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Vasantha Vallabha Nagar',
#   'size': '3 Bedroom',
#   'society': nan,
#   'total_sqft': '1500',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 95.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Sahakara Nagar',
#   'size': '3 BHK',
#   'society': 'EsniaGa',
#   'total_sqft': '1500',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 95.0},
#  {'area_type': 'Plot  Area',
#   'availability': 'Ready To Move',
#   'location': 'Yelahanka',
#   'size': '4 Bedroom',
#   'society': 'Aaire S',
#   'total_sqft': '3206',
#   'bath': 5.0,
#   'balcony': nan,
#   'price': 270.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Uttarahalli',
#   'size': '3 BHK',
#   'society': 'Laihai ',
#   'total_sqft': '1540',
#   'bath': 3.0,
#   'balcony': 0.0,
#   'price': 50.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': '18-May',
#   'location': 'Hosa Road',
#   'size': '3 BHK',
#   'society': 'Pamesy ',
#   'total_sqft': '1639',
#   'bath': 3.0,
#   'balcony': 1.0,
#   'price': 80.0},
#  {'area_type': 'Plot  Area',
#   'availability': 'Ready To Move',
#   'location': 'Marathahalli',
#   'size': '4 Bedroom',
#   'society': nan,
#   'total_sqft': '700',
#   'bath': 4.0,
#   'balcony': nan,
#   'price': 72.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Raja Rajeshwari Nagar',
#   'size': '2 BHK',
#   'society': 'GrrvaGr',
#   'total_sqft': '1303',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 55.79},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Koramangala',
#   'size': '2 BHK',
#   'society': 'K ncy R',
#   'total_sqft': '1005',
#   'bath': 1.0,
#   'balcony': 1.0,
#   'price': 110.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Kammasandra',
#   'size': '1 BHK',
#   'society': 'Puitea ',
#   'total_sqft': '650 - 665',
#   'bath': 1.0,
#   'balcony': 0.0,
#   'price': 18.41},
#  {'area_type': 'Super built-up  Area',
#   'availability': '18-Oct',
#   'location': 'Chandapura',
#   'size': '3 BHK',
#   'society': 'SunceEs',
#   'total_sqft': '1305',
#   'bath': 3.0,
#   'balcony': 1.0,
#   'price': 33.28},
#  {'area_type': 'Plot  Area',
#   'availability': 'Ready To Move',
#   'location': 'Kothannur',
#   'size': '3 Bedroom',
#   'society': nan,
#   'total_sqft': '600',
#   'bath': 4.0,
#   'balcony': 0.0,
#   'price': 95.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'sapthagiri Layout',
#   'size': '2 BHK',
#   'society': nan,
#   'total_sqft': '1300',
#   'bath': 1.0,
#   'balcony': 1.0,
#   'price': 115.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Brookefield',
#   'size': '3 BHK',
#   'society': 'Saowson',
#   'total_sqft': '1440',
#   'bath': 2.0,
#   'balcony': 3.0,
#   'price': 68.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': '18-Dec',
#   'location': 'Seegehalli',
#   'size': '2 BHK',
#   'society': nan,
#   'total_sqft': '901',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 35.14},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Rajaji Nagar',
#   'size': '3 BHK',
#   'society': 'Brway G',
#   'total_sqft': '1725',
#   'bath': 3.0,
#   'balcony': 3.0,
#   'price': 200.0},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Sarjapur',
#   'size': '3 BHK',
#   'society': nan,
#   'total_sqft': '900',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 42.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'BEML Layout',
#   'size': '2 BHK',
#   'society': nan,
#   'total_sqft': '1060',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 55.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'NGR Layout',
#   'size': '2 BHK',
#   'society': nan,
#   'total_sqft': '1020',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 48.45},
#  {'area_type': 'Super built-up  Area',
#   'availability': '20-Dec',
#   'location': 'Varthur',
#   'size': '3 BHK',
#   'society': 'Myple M',
#   'total_sqft': '1535',
#   'bath': 3.0,
#   'balcony': 2.0,
#   'price': 65.99},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Alur',
#   'size': '1 BHK',
#   'society': nan,
#   'total_sqft': '530',
#   'bath': 1.0,
#   'balcony': 1.0,
#   'price': 20.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Haralur Road',
#   'size': '3 BHK',
#   'society': 'NRowse ',
#   'total_sqft': '1464',
#   'bath': 3.0,
#   'balcony': 2.0,
#   'price': 56.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Devarabisanahalli',
#   'size': '2 BHK',
#   'society': 'Spdoren',
#   'total_sqft': '1350',
#   'bath': 2.0,
#   'balcony': 3.0,
#   'price': 80.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Sarjapur  Road',
#   'size': '2 BHK',
#   'society': nan,
#   'total_sqft': '1115',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 50.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Uttarahalli',
#   'size': '2 BHK',
#   'society': nan,
#   'total_sqft': '1175',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 47.0},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Whitefield',
#   'size': '2 BHK',
#   'society': nan,
#   'total_sqft': '1113',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 62.0},
#  {'area_type': 'Plot  Area',
#   'availability': 'Ready To Move',
#   'location': 'Uttarahalli',
#   'size': '6 Bedroom',
#   'society': nan,
#   'total_sqft': '1200',
#   'bath': 4.0,
#   'balcony': 2.0,
#   'price': 225.0},
#  {'area_type': 'Plot  Area',
#   'availability': 'Ready To Move',
#   'location': 'Ramamurthy Nagar',
#   'size': '5 Bedroom',
#   'society': nan,
#   'total_sqft': '1640',
#   'bath': 4.0,
#   'balcony': 3.0,
#   'price': 240.0},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Giri Nagar',
#   'size': '2 BHK',
#   'society': 'Spanda ',
#   'total_sqft': '650',
#   'bath': 2.0,
#   'balcony': 0.0,
#   'price': 42.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Marathahalli',
#   'size': '2 BHK',
#   'society': nan,
#   'total_sqft': '1325',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 71.55},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Electronics City Phase 1',
#   'size': '2 BHK',
#   'society': 'Shelash',
#   'total_sqft': '950',
#   'bath': 2.0,
#   'balcony': 3.0,
#   'price': 31.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': '18-Apr',
#   'location': 'Jakkur',
#   'size': '3 BHK',
#   'society': nan,
#   'total_sqft': '1396',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 86.51},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Rachenahalli',
#   'size': '2 BHK',
#   'society': nan,
#   'total_sqft': '1050',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 52.07},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Thanisandra',
#   'size': '3 BHK',
#   'society': nan,
#   'total_sqft': '1825',
#   'bath': 3.0,
#   'balcony': 2.0,
#   'price': 100.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': '7th Phase JP Nagar',
#   'size': '2 BHK',
#   'society': 'Vasta C',
#   'total_sqft': '1190',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 49.98},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Marathahalli',
#   'size': '2 BHK',
#   'society': nan,
#   'total_sqft': '1220',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 56.5},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'NRI Layout',
#   'size': '3 BHK',
#   'society': nan,
#   'total_sqft': '1565',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 75.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Hennur Road',
#   'size': '3 BHK',
#   'society': 'SaireSa',
#   'total_sqft': '1891',
#   'bath': 3.0,
#   'balcony': 1.0,
#   'price': 109.0},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Sidedahalli',
#   'size': '2 BHK',
#   'society': nan,
#   'total_sqft': '900',
#   'bath': 2.0,
#   'balcony': 0.0,
#   'price': 27.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': '18-Jul',
#   'location': 'Hosa Road',
#   'size': '2 BHK',
#   'society': 'Mahesr ',
#   'total_sqft': '1161',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 55.15},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Sarjapur',
#   'size': '1 BHK',
#   'society': 'DSousyl',
#   'total_sqft': '633 - 666',
#   'bath': 1.0,
#   'balcony': 0.0,
#   'price': 17.535},
#  {'area_type': 'Plot  Area',
#   'availability': 'Ready To Move',
#   'location': 'Dwarka Nagar',
#   'size': '8 Bedroom',
#   'society': nan,
#   'total_sqft': '2400',
#   'bath': 6.0,
#   'balcony': 3.0,
#   'price': 125.0},
#  {'area_type': 'Plot  Area',
#   'availability': 'Ready To Move',
#   'location': 'Rajaji Nagar',
#   'size': '4 Bedroom',
#   'society': nan,
#   'total_sqft': '315',
#   'bath': 4.0,
#   'balcony': 2.0,
#   'price': 90.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Yeshwanthpur',
#   'size': '1 BHK',
#   'society': 'IBityin',
#   'total_sqft': '665',
#   'bath': 1.0,
#   'balcony': 1.0,
#   'price': 36.85},
#  {'area_type': 'Super built-up  Area',
#   'availability': '19-Jan',
#   'location': 'Mysore Road',
#   'size': '2 BHK',
#   'society': nan,
#   'total_sqft': '1175',
#   'bath': 2.0,
#   'balcony': 1.0,
#   'price': 73.5},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Hoodi',
#   'size': '2 BHK',
#   'society': 'Goeur G',
#   'total_sqft': '1425',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 80.0},
#  {'area_type': 'Plot  Area',
#   'availability': 'Ready To Move',
#   'location': 'Chikkabanavar',
#   'size': '1 Bedroom',
#   'society': nan,
#   'total_sqft': '1200',
#   'bath': 1.0,
#   'balcony': 0.0,
#   'price': 20.0},
#  {'area_type': 'Plot  Area',
#   'availability': '18-Aug',
#   'location': 'ITPL',
#   'size': '3 Bedroom',
#   'society': nan,
#   'total_sqft': '1200',
#   'bath': 3.0,
#   'balcony': 1.0,
#   'price': 56.12},
#  {'area_type': 'Built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Somasundara Palya',
#   'size': '2 BHK',
#   'society': 'Abeesmi',
#   'total_sqft': '1255',
#   'bath': 2.0,
#   'balcony': 2.0,
#   'price': 67.0},
#  {'area_type': 'Super built-up  Area',
#   'availability': 'Ready To Move',
#   'location': 'Hegde Nagar',
#   'size': '3 BHK',
#   'society': 'SoisoCa',
#   'total_sqft': '2112.95',
#   'bath': 4.0,
#   'balcony': 2.0,
#   'price': 145.0},
#  ...]

# %%
##remove your credentials or delete the mongodb resource before pushing it to github
DB_NAME = "Housing"
COLLECTION_NAME = "Housing-Data"
CONNECTION_URL = ""

# %%
client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]
# Out:
# C:\Users\DELL\AppData\Roaming\Python\Python313\site-packages\pymongo\pyopenssl_context.py:348: CryptographyDeprecationWarning: Parsed a serial number which wasn't positive (i.e., it was negative or zero), which is disallowed by RFC 5280. Loading this certificate will cause an exception in a future release of cryptography.
#   _crypto.X509.from_cryptography(x509.load_der_x509_certificate(cert))

# %%
## Uploading data to mongodb
rec = collection.insert_many(data)

# %%
print(type(rec))
# Out:
# <class 'pymongo.results.InsertManyResult'>
